# %% [markdown]
# <a href="https://colab.research.google.com/github/VarshiniRajesh14/My-files/blob/main/MiniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas numpy matplotlib seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings("ignore",category=UndefinedMetricWarning)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-47698972-e350-43ba-8605-31929c652eb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47698972-e350-43ba-8605-31929c652eb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

data=pd.read_csv(io.BytesIO(uploaded['advertising(1) (11).csv']))

# %%
data.info()
data.describe()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(numeric_only=True),annot=True,cmap='Greens')
plt.title("Correlation Heatmap")
plt.show()
sns.pairplot(data,hue="Clicked on Ad")
plt.show()

# %%
x=data[['Daily Time Spent on Site','Age','Area Income','Daily Internet Usage']]
y=data['Clicked on Ad']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print("Training data shape:",x_train.shape)
print("Testing data shape:",x_test.shape)
print("First few y_train values:\n",y_train[:10])
# Out:
# Training data shape: (700, 4)
# Testing data shape: (300, 4)
# First few y_train values:
#  541    0
# 440    1
# 482    0
# 422    1
# 778    1
# 949    1
# 334    0
# 576    1
# 934    0
# 567    0
# Name: Clicked on Ad, dtype: int64

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
print(type(model))
print(model)
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# LogisticRegression(max_iter=500)

# %%
model=LogisticRegression(max_iter=500)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=500)
model.fit(x_train,y_train)
print("Model retrained successfully")
print("Has coefficients?->",hasattr(model,"coef_"))
if hasattr(model,"coef_"):
  coeff_df=pd.DataFrame(model.coef_[0],index=['Daily Time Spent on Site','Age','Area Income','Daily Internet Usage'],columns=['Coefficient'])
  print("\nFeature Influence on ad click:")
  print(coeff_df)
else:
  print("Model still not trained-ckeck x_train and y_train content.")
# Out:
# Model retrained successfully
# Has coefficients?-> True
#
# Feature Influence on ad click:
#                           Coefficient
# Daily Time Spent on Site    -0.187507
# Age                          0.175901
# Area Income                 -0.000141
# Daily Internet Usage        -0.071580

# %%
y_pred=model.predict(x_test)

# %%
print("\nConclusion Matrix:")
print(confusion_matrix(y_test,y_pred))
print("\nClassification Report:")
print(classification_report(y_test,y_pred))
print("\nModel Accuracy:",
accuracy_score(y_test,y_pred))
# Out:
# Conclusion Matrix:
# [[143   3]
#  [  8 146]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       146
#            1       0.98      0.95      0.96       154
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.96      0.96       300
# weighted avg       0.96      0.96      0.96       300
#
#
# Model Accuracy: 0.9633333333333334

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,fmt='d',cmap='Reds')
plt.title("Confusion Matrix Visualization")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
coeff_df=pd.DataFrame(model.coef_[0],x.columns,columns=['Coefficient'])
print("\nFeature Influence on Ad Click:")
print(coeff_df)
# Out:
# Feature Influence on Ad Click:
#                           Coefficient
# Daily Time Spent on Site    -0.187507
# Age                          0.175901
# Area Income                 -0.000141
# Daily Internet Usage        -0.071580
